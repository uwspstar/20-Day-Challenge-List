# %% [markdown]
# Here’s the detailed breakdown of the solution to the LeetCode problem "Number of 1 Bits" using the specified template:
#
# ### LeetCode 题目：191. 位1的个数
#
# https://leetcode.com/problems/number-of-1-bits/description/
#
# #### 问题描述：
# 编写一个函数，计算二进制中1的个数。
#
# #### 示例 1：
# ```python
# 输入：n = 00000000000000000000000000001011
# 输出：3
# 解释：输入的二进制表示中有三位是1。
# ```
#
# #### 示例 2：
# ```python
# 输入：n = 00000000000000000000000010000000
# 输出：1
# ```
#
# ### 改进后的代码：
#
# ```python
# class Solution:
#     def hammingWeight(self, n: int) -> int:
#         res = 0  # 初始化计数器
#         while n:  # 当 n 不为 0 时继续循环
#             res += 1  # 每次找到一个1位时，计数增加
#             n = n & (n - 1)  # 利用 n & (n - 1) 移除最低位的1
#
#         return res  # 返回1的总数
# ```
#
# ### 改进点解释：
#
# 1. **移除右移操作**：
#    - 右移操作会逐位处理，效率较低。而使用 `n & (n - 1)` 可以直接移除最低位的1，这样效率更高。
#
# 2. **清晰的变量命名**：
#    - 代码保持了清晰的注释，便于理解每一步的作用。
#
# ### 时间复杂度分析：
#
# - **时间复杂度**：O(k)
#   - 这里 k 是 n 中1的位数，最坏情况下需要遍历所有1位。
#
# - **空间复杂度**：O(1)
#   - 只使用了常量级的额外空间来存储 `res` 变量。
#
# ### 总结：
#
# - **位运算技巧**：利用位运算中的技巧，能够高效计算二进制中1的个数。
# - **高效性**：通过直接移除最低位的1，算法在处理较大数值时仍能保持高效。
#
# 如果你有其他问题或需要进一步讨论，请随时告诉我！
